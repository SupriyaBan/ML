# %% [markdown]
# # Task 3 GRIP
# # Decision Tree Classifier

# %% [markdown]
# By Supriya Banerjee

# %%
# Importing libraries 
import sklearn.datasets as datasets
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
# Getting the data
data=pd.read_csv("C:/Users/pradipbanerjee/Downloads/Iris.csv")
z=data.head()
z
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Defining the variables
x=z[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']].values
y=z['Species'].values

# %%
# Dividing into training and testing data
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest=train_test_split(x,y,test_size=0.3,random_state=1)
xtrain; xtest; ytrain; ytest
# Out:
# array(['Iris-setosa', 'Iris-setosa'], dtype=object)

# %%
# Setting up decision tree classifier
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
a=model.fit(xtrain,ytrain)
a
print('Decision Tree Classifer Created')
# Out:
# Decision Tree Classifer Created

# %%
# The prediction
value=model.predict(xtest)
print("Predicted value is ",value)
print("The score is ",model.score(xtest,ytest))
# Out:
# Predicted value is  ['Iris-setosa' 'Iris-setosa']
# The score is  1.0

# %%
# The decision tree
from sklearn import tree
I=data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
D=data['Species']
modelfinal=model.fit(I,D)
plt.rcParams["figure.figsize"] = [16,9]
tree.plot_tree(modelfinal,filled=True )
# Out:
# [Text(446.4, 448.47, 'X[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(377.7230769230769, 366.93, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(515.0769230769231, 366.93, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(274.7076923076923, 285.39, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(137.35384615384615, 203.84999999999997, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(68.67692307692307, 122.31, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(206.03076923076924, 122.31, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(412.0615384615385, 203.84999999999997, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(343.38461538461536, 122.31, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(480.73846153846154, 122.31, 'X[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...
